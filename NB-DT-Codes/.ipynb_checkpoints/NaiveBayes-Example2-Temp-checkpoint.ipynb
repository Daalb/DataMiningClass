# %% [markdown]
# # Naive Bayes Classifier

# %% [markdown]
# $P(c|x)=P(c)\prod_{i=1}^{n}{P(X_i|c)}$

# %% [markdown]
# ***

# %% [markdown]
# Data Information:<br>
#
# RI: refractive index<br>
# Na: Sodium (unit measurement: weight percent in corresponding oxide, as are attributes 4-10)<br>
# Mg: Magnesium<br>
# Al: Aluminum<br>
# Si: Silicon<br>
# K: Potassium<br>
# Ca: Calcium<br>
# Ba: Barium<br>
# Fe: Iron<br>
#
# **Type of glass**: (class) – window glass (from vehicle or building) ... not window glass (containers, tableware, or headlamps)

# %%
#Import all libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.naive_bayes import GaussianNB
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.model_selection import train_test_split #Nos permite separar el conjunto de datos
#import warnings
#warnings.filterwarnings('ignore')

# %%
#Load the dataset
df = pd.read_csv("glass.csv")

#Top 5 our data
df.head()
# Out:
#         RI     Na    Mg    Al     Si     K    Ca   Ba   Fe  Type
# 0  1.52101  13.64  4.49  1.10  71.78  0.06  8.75  0.0  0.0     1
# 1  1.51761  13.89  3.60  1.36  72.73  0.48  7.83  0.0  0.0     1
# 2  1.51618  13.53  3.55  1.54  72.99  0.39  7.78  0.0  0.0     1
# 3  1.51766  13.21  3.69  1.29  72.61  0.57  8.22  0.0  0.0     1
# 4  1.51742  13.27  3.62  1.24  73.08  0.55  8.07  0.0  0.0     1

# %%
#Top 5 data from bottom
df.tail()
# Out:
#           RI     Na   Mg    Al     Si     K    Ca    Ba   Fe  Type
# 209  1.51623  14.14  0.0  2.88  72.61  0.08  9.18  1.06  0.0     7
# 210  1.51685  14.92  0.0  1.99  73.06  0.00  8.40  1.59  0.0     7
# 211  1.52065  14.36  0.0  2.02  73.42  0.00  8.44  1.64  0.0     7
# 212  1.51651  14.38  0.0  1.94  73.61  0.00  8.48  1.57  0.0     7
# 213  1.51711  14.23  0.0  2.08  73.36  0.00  8.62  1.67  0.0     7

# %%
#Check if data is clean so can continue to the Explorary Data Analysis stage
df.isnull().sum()
# Out:
# RI      0
# Na      0
# Mg      0
# Al      0
# Si      0
# K       0
# Ca      0
# Ba      0
# Fe      0
# Type    0
# dtype: int64

# %%
#Univariate analysis Type (Target features).
sns.countplot(df['Type'], color='red')

# %%
#Univariate analysis of RI (Refractive Index).
f = plt.figure(figsize=(20,4))
f.add_subplot(1,2,1)
sns.distplot(df['RI'])
f.add_subplot(1,2,2)
sns.boxplot(df['RI']);

# %%
#Univariate analysis Na (Sodium).#Aquí se hizo con otro atributo, se puede hacer con todos
f = plt.figure(figsize=(20,4))
f.add_subplot(1,2,1)
sns.distplot(df['Na'], color='green')
f.add_subplot(1,2,2)
sns.boxplot(df['Na'], color='green')

# %%
#Correlation between features
df.corr().style.background_gradient().set_precision(2)
#Entre más oscuro mayor correlación
# Out:
# <style  type="text/css" >
#     #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col1 {
#             background-color:  #f5eff6;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col2 {
#             background-color:  #acc0dd;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col3 {
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col4 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col5 {
#             background-color:  #fcf4fa;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col6 {
#             background-color:  #045b8e;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col7 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col8 {
#             background-color:  #bcc7e1;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row0_col9 {
#             background-color:  #b4c4df;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col0 {
#             background-color:  #d5d5e8;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col2 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col3 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col4 {
#             background-color:  #bdc8e1;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col5 {
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col6 {
#             background-color:  #eee8f3;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col7 {
#             background-color:  #5c9fc9;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col8 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row1_col9 {
#             background-color:  #1278b4;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col0 {
#             background-color:  #c9cee4;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col2 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col3 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col4 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col5 {
#             background-color:  #d2d2e7;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col6 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col7 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col8 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row2_col9 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col0 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col1 {
#             background-color:  #b3c3de;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col2 {
#             background-color:  #e7e3f0;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col3 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col4 {
#             background-color:  #afc1dd;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col5 {
#             background-color:  #78abd0;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col6 {
#             background-color:  #ece7f2;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col7 {
#             background-color:  #2c89bd;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col8 {
#             background-color:  #eae6f1;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row3_col9 {
#             background-color:  #056caa;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col1 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col2 {
#             background-color:  #b5c4df;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col3 {
#             background-color:  #b8c6e0;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col4 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col5 {
#             background-color:  #f1ebf4;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col6 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col7 {
#             background-color:  #cdd0e5;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col8 {
#             background-color:  #ede8f3;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row4_col9 {
#             background-color:  #6da6cd;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col0 {
#             background-color:  #e4e1ef;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col1 {
#             background-color:  #fef6fb;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col2 {
#             background-color:  #8fb4d6;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col3 {
#             background-color:  #5ea0ca;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col4 {
#             background-color:  #d6d6e9;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col5 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col6 {
#             background-color:  #f2ecf5;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col7 {
#             background-color:  #bfc9e1;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col8 {
#             background-color:  #dedcec;
#             color:  #000000;
#         }    #T_7c8de989_0e7e_11eb_9e77_706655578622row5_col9 {
#             background-color:  #94b6d7;
#             color:  #000000;

# %%
# Create a Naive Bayes object
nb = GaussianNB()

#Create variable x and y.
x = df.drop(columns=['Type'])
y = df['Type']

#Split data into training and testing data
x_train, x_test, y_train, y_test = train_test_split(x, y , test_size=0.2, random_state=4)

#Training the model
nb.fit(x_train,y_train )#Para que se ajusten al modelo

#Predict testing set
y_pred = nb.predict(x_test)

#Check performance of model
print("Accuracy:",accuracy_score(y_test,y_pred))
# Out:
# Accuracy: 0.4883720930232558

# %%
print("Precision:",precision_score(y_test,y_pred , average='micro'))
# Out:
# Precision: 0.4883720930232558

# %%
y_pred
# Out:
# array([1, 7, 5, 3, 3, 1, 2, 1, 1, 1, 5, 1, 1, 7, 1, 1, 1, 7, 7, 1, 1, 1,
#        7, 1, 6, 7, 3, 3, 7, 2, 1, 7, 1, 1, 1, 1, 1, 2, 1, 1, 5, 7, 2],
#       dtype=int64)

# %%
predicted = nb.predict([[1.5,10,1.01,1.3,70,0.5,11,2,0.4]])  
predicted 
#Con base a los datos pasados me dice que es de tipo 2
# Out:
# array([2], dtype=int64)
