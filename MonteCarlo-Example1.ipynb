# %%
import numpy as np
from scipy.stats import binom
import random
import matplotlib.pyplot as plt

binom.pmf(3, 10, 0.5)+binom.pmf(6, 10, 0.5)+binom.pmf(9, 10, 0.5)
# Out:
# 0.33203125000000033

# %%
import numpy as np
from scipy.stats import uniform

N=1000
T=0

for i in range(N):
    x = uniform.rvs(size=10)
    h=0
    for xi in x:
        if  xi<0.5:
            h+=1
    
    if h==3 or h==6 or h==9:
        T+=1

        
print(T/N)
# Out:
# 0.327

# %%
#Simulo los lanzamientos
def lanzamiento():
    num = random.randint(1,100)
    if 1<=num<=51:
        return False;
    else:
        return True;

# %%
def apuesta(x,dinero,monto):
    for i in x:
        if lanzamiento():
            dinero = dinero + monto
        else:
            dinero = dinero - monto

# %%
num_simulaciones = 100
x = np.mgrid[1:20:100j]
montos = []

for i in range(num_simulaciones):
    apuesta(x,10000,100)
